# %%
# =============================================================
# Full Working DRL (PPO) Gait Recognition Script for Colab
# =============================================================

# 1. Install dependencies
# !pip install stable-baselines3

# 2. Import Libraries
import os
import gymnasium as gym
from gymnasium import spaces

import numpy as np
import cv2
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env

# 3. Set Dataset Path
DATASET_PATH = '/content/drive/MyDrive/Dataset/062'  # <<== Change this to your path

# 4. Load Silhouette Images
def load_images_universal(folder, target_size=(64, 64)):
    images = []
    labels = []
    label_to_idx = {}
    current_label_idx = 0

    def is_image_file(filename):
        return filename.lower().endswith(('.png', '.jpg', '.jpeg'))

    for root, dirs, files in os.walk(folder):
        image_files = [f for f in files if is_image_file(f)]
        if image_files:  # If there are image files in this folder
            class_folder = os.path.basename(root)
            if class_folder not in label_to_idx:
                label_to_idx[class_folder] = current_label_idx
                current_label_idx += 1
            for img_file in image_files:
                img_path = os.path.join(root, img_file)
                img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                if img is None:
                    continue
                img = cv2.resize(img, target_size)
                images.append(img)
                labels.append(label_to_idx[class_folder])

    return np.array(images), np.array(labels)


silhouette_images, gait_labels = load_images_universal(DATASET_PATH)
print(silhouette_images.shape, gait_labels.shape)
silhouette_images = silhouette_images / 255.0
silhouette_images = silhouette_images[..., np.newaxis]
print(f"✅ Loaded {len(silhouette_images)} images!")

# 5. Feature Extractor CNN
class FeatureExtractor(nn.Module):
    def __init__(self):
        super(FeatureExtractor, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(1, 32, 3, 1, 1), nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(32, 64, 3, 1, 1), nn.ReLU(), nn.MaxPool2d(2),
            nn.Flatten()
        )
        self.fc = nn.Linear(64 * 16 * 16, 128)

    def forward(self, x):
        x = self.conv(x)
        x = self.fc(x)
        return x

# 6. Dataset and Feature Extraction
class GaitDataset(Dataset):
    def __init__(self, images, labels):
        self.images = torch.tensor(images, dtype=torch.float32).permute(0, 3, 1, 2)
        self.labels = torch.tensor(labels, dtype=torch.long)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        return self.images[idx], self.labels[idx]

train_dataset = GaitDataset(silhouette_images, gait_labels)
loader = DataLoader(train_dataset, batch_size=64, shuffle=False)

feature_extractor = FeatureExtractor()
feature_extractor.eval()

feature_list = []
label_list = []

with torch.no_grad():
    for images, labels in loader:
        feats = feature_extractor(images)
        feature_list.append(feats)
        label_list.append(labels)

features = torch.cat(feature_list).numpy()
labels = torch.cat(label_list).numpy()
print(f"✅ Extracted {features.shape[0]} features of dimension {features.shape[1]}")

# 7. Define Gait Environment
class GaitEnv(gym.Env):
    def __init__(self, features, labels):
        super(GaitEnv, self).__init__()
        self.features = features
        self.labels = labels
        self.num_samples = len(features)
        self.current_idx = 0

        self.action_space = spaces.Discrete(len(np.unique(labels)))
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(features.shape[1],), dtype=np.float32)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_idx = np.random.randint(0, self.num_samples)
        return self.features[self.current_idx], {}

    def step(self, action):
        correct_label = self.labels[self.current_idx]
        reward = 1 if action == correct_label else 0
        done = True
        info = {}
        next_obs = self.features[np.random.randint(0, self.num_samples)]
        return next_obs, reward, done, False, info


# 8. Train PPO Agent
env = GaitEnv(features, labels)
check_env(env)

model = PPO('MlpPolicy', env, verbose=1, batch_size=64, learning_rate=1e-4)
model.learn(total_timesteps=500000)

# 9. Evaluate Agent
correct = 0
total = 200

for _ in range(total):
    obs, _ = env.reset()  # <- unpack properly
    action, _ = model.predict(obs, deterministic=True)
    if action == env.labels[env.current_idx]:
        correct += 1

print(f"🎯 Final DRL PPO Test Accuracy: {correct/total:.4f}")
# Out:
# Streaming output truncated to the last 5000 lines.
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.09        |
# | time/                   |             |
# |    fps                  | 639         |
# |    iterations           | 8           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.020468898 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.12       |
# |    explained_variance   | 0.0119      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0231      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0283     |
# |    value_loss           | 0.109       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.13        |
# | time/                   |             |
# |    fps                  | 642         |
# |    iterations           | 9           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.012490859 |
# |    clip_fraction        | 0.0805      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | 0.0114      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00419    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0184     |
# |    value_loss           | 0.107       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.21        |
# | time/                   |             |
# |    fps                  | 644         |
# |    iterations           | 10          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.014676765 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.92       |
# |    explained_variance   | 0.0129      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0436      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0213     |
# |    value_loss           | 0.114       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.18       |
# | time/                   |            |
# |    fps                  | 629        |
# |    iterations           | 11         |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.01250782 |
# |    clip_fraction        | 0.11       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.8       |
# |    explained_variance   | 0.0204     |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.0231     |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0211    |
# |    value_loss           | 0.135      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.18        |
# | time/                   |             |
# |    fps                  | 631         |
# |    iterations           | 12          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.013387704 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0.021       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0486      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0267     |
# |    value_loss           | 0.151       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.2         |
# | time/                   |             |
# |    fps                  | 633         |
# |    iterations           | 13          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.014233209 |
# |    clip_fraction        | 0.0923      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.64       |
# |    explained_variance   | 0.0439      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0812      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0201     |
# |    value_loss           | 0.14        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.16       |
# | time/                   |            |
# |    fps                  | 636        |
# |    iterations           | 14         |
# |    time_elapsed         | 45         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.01150024 |
# |    clip_fraction        | 0.0756     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.54      |
# |    explained_variance   | 0.0391     |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.043      |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0168    |
# |    value_loss           | 0.155      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.17        |
# | time/                   |             |
# |    fps                  | 629         |
# |    iterations           | 15          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009955805 |
# |    clip_fraction        | 0.0914      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.0619      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0293      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0156     |
# |    value_loss           | 0.147       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.23        |
# | time/                   |             |
# |    fps                  | 626         |
# |    iterations           | 16          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010839613 |
# |    clip_fraction        | 0.0957      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.0685      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0413      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 0.149       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.23         |
# | time/                   |              |
# |    fps                  | 628          |
# |    iterations           | 17           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0068476014 |
# |    clip_fraction        | 0.0389       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.0661       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0711       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0098      |
# |    value_loss           | 0.156        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.29        |
# | time/                   |             |
# |    fps                  | 630         |
# |    iterations           | 18          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.004573101 |
# |    clip_fraction        | 0.0391      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.105       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0663      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00973    |
# |    value_loss           | 0.158       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.18        |
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 19          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.006947378 |
# |    clip_fraction        | 0.0491      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.114       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0342      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 0.159       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.25        |
# | time/                   |             |
# |    fps                  | 623         |
# |    iterations           | 20          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.005862352 |
# |    clip_fraction        | 0.0434      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.109       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0637      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 0.163       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.19        |
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 21          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.007029717 |
# |    clip_fraction        | 0.0522      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.12        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.049       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 0.164       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.23        |
# | time/                   |             |
# |    fps                  | 627         |
# |    iterations           | 22          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.006845643 |
# |    clip_fraction        | 0.0481      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.935      |
# |    explained_variance   | 0.15        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0505      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.167       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.28        |
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 23          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.004469709 |
# |    clip_fraction        | 0.016       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.858      |
# |    explained_variance   | 0.135       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0671      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00748    |
# |    value_loss           | 0.168       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.25         |
# | time/                   |              |
# |    fps                  | 621          |
# |    iterations           | 24           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0037463144 |
# |    clip_fraction        | 0.0201       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.819       |
# |    explained_variance   | 0.146        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.081        |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00763     |
# |    value_loss           | 0.165        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.18         |
# | time/                   |              |
# |    fps                  | 623          |
# |    iterations           | 25           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0034102069 |
# |    clip_fraction        | 0.0198       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.76        |
# |    explained_variance   | 0.164        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0522       |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00634     |
# |    value_loss           | 0.166        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.31         |
# | time/                   |              |
# |    fps                  | 624          |
# |    iterations           | 26           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0030498458 |
# |    clip_fraction        | 0.0203       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.721       |
# |    explained_variance   | 0.149        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0686       |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00683     |
# |    value_loss           | 0.156        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.21         |
# | time/                   |              |
# |    fps                  | 623          |
# |    iterations           | 27           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0046103755 |
# |    clip_fraction        | 0.0427       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.676       |
# |    explained_variance   | 0.171        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0612       |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00824     |
# |    value_loss           | 0.167        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.26         |
# | time/                   |              |
# |    fps                  | 620          |
# |    iterations           | 28           |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0039720475 |
# |    clip_fraction        | 0.0255       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.642       |
# |    explained_variance   | 0.185        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0728       |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00561     |
# |    value_loss           | 0.156        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.33         |
# | time/                   |              |
# |    fps                  | 621          |
# |    iterations           | 29           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0029477528 |
# |    clip_fraction        | 0.0285       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.59        |
# |    explained_variance   | 0.155        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0738       |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0054      |
# |    value_loss           | 0.176        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.28         |
# | time/                   |              |
# |    fps                  | 622          |
# |    iterations           | 30           |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0027145243 |
# |    clip_fraction        | 0.017        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.581       |
# |    explained_variance   | 0.202        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.078        |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00585     |
# |    value_loss           | 0.162        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.29         |
# | time/                   |              |
# |    fps                  | 622          |
# |    iterations           | 31           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0023076436 |
# |    clip_fraction        | 0.0202       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.547       |
# |    explained_variance   | 0.174        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0714       |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00491     |
# |    value_loss           | 0.17         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.28         |
# | time/                   |              |
# |    fps                  | 618          |
# |    iterations           | 32           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0035391008 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.513       |
# |    explained_variance   | 0.205        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0738       |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0056      |
# |    value_loss           | 0.16         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.27       |
# | time/                   |            |
# |    fps                  | 619        |
# |    iterations           | 33         |
# |    time_elapsed         | 109        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.00216777 |
# |    clip_fraction        | 0.0237     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.481     |
# |    explained_variance   | 0.22       |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.0913     |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.00498   |
# |    value_loss           | 0.161      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.33         |
# | time/                   |              |
# |    fps                  | 620          |
# |    iterations           | 34           |
# |    time_elapsed         | 112          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0038072243 |
# |    clip_fraction        | 0.0251       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.471       |
# |    explained_variance   | 0.184        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0811       |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00344     |
# |    value_loss           | 0.167        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.37         |
# | time/                   |              |
# |    fps                  | 620          |
# |    iterations           | 35           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0024827719 |
# |    clip_fraction        | 0.0213       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.486       |
# |    explained_variance   | 0.182        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0966       |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00438     |
# |    value_loss           | 0.17         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.31         |
# | time/                   |              |
# |    fps                  | 617          |
# |    iterations           | 36           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0036829656 |
# |    clip_fraction        | 0.038        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.464       |
# |    explained_variance   | 0.215        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0783       |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00488     |
# |    value_loss           | 0.169        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.31         |
# | time/                   |              |
# |    fps                  | 617          |
# |    iterations           | 37           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0021907557 |
# |    clip_fraction        | 0.0238       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.475       |
# |    explained_variance   | 0.206        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0602       |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00415     |
# |    value_loss           | 0.167        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.21         |
# | time/                   |              |
# |    fps                  | 618          |
# |    iterations           | 38           |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0013351922 |
# |    clip_fraction        | 0.0217       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.466       |
# |    explained_variance   | 0.217        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0761       |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00294     |
# |    value_loss           | 0.168        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.32        |
# | time/                   |             |
# |    fps                  | 619         |
# |    iterations           | 39          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.004074081 |
# |    clip_fraction        | 0.0263      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.452      |
# |    explained_variance   | 0.235       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0723      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0034     |
# |    value_loss           | 0.158       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.32         |
# | time/                   |              |
# |    fps                  | 615          |
# |    iterations           | 40           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0028379243 |
# |    clip_fraction        | 0.0339       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.423       |
# |    explained_variance   | 0.278        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0578       |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00438     |
# |    value_loss           | 0.157        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.35        |
# | time/                   |             |
# |    fps                  | 616         |
# |    iterations           | 41          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.004131146 |
# |    clip_fraction        | 0.041       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.426      |
# |    explained_variance   | 0.221       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0748      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00537    |
# |    value_loss           | 0.168       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.31        |
# | time/                   |             |
# |    fps                  | 617         |
# |    iterations           | 42          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.002329009 |
# |    clip_fraction        | 0.0273      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.425      |
# |    explained_variance   | 0.245       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0667      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00395    |
# |    value_loss           | 0.158       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.26         |
# | time/                   |              |
# |    fps                  | 618          |
# |    iterations           | 43           |
# |    time_elapsed         | 142          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0036792099 |
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.4         |
# |    explained_variance   | 0.231        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0734       |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0048      |
# |    value_loss           | 0.158        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.39         |
# | time/                   |              |
# |    fps                  | 614          |
# |    iterations           | 44           |
# |    time_elapsed         | 146          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0023675086 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.376       |
# |    explained_variance   | 0.249        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0871       |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00483     |
# |    value_loss           | 0.166        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.28         |
# | time/                   |              |
# |    fps                  | 615          |
# |    iterations           | 45           |
# |    time_elapsed         | 149          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0028545314 |
# |    clip_fraction        | 0.0319       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.352       |
# |    explained_variance   | 0.266        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0464       |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00442     |
# |    value_loss           | 0.161        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.29         |
# | time/                   |              |
# |    fps                  | 616          |
# |    iterations           | 46           |
# |    time_elapsed         | 152          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0022576428 |
# |    clip_fraction        | 0.0346       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.368       |
# |    explained_variance   | 0.237        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0808       |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00307     |
# |    value_loss           | 0.16         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.36         |
# | time/                   |              |
# |    fps                  | 617          |
# |    iterations           | 47           |
# |    time_elapsed         | 155          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0017160835 |
# |    clip_fraction        | 0.0161       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.356       |
# |    explained_variance   | 0.218        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0688       |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.0017      |
# |    value_loss           | 0.162        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.26         |
# | time/                   |              |
# |    fps                  | 614          |
# |    iterations           | 48           |
# |    time_elapsed         | 159          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0028596527 |
# |    clip_fraction        | 0.0352       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.339       |
# |    explained_variance   | 0.234        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0751       |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00411     |
# |    value_loss           | 0.164        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.34        |
# | time/                   |             |
# |    fps                  | 615         |
# |    iterations           | 49          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.002087594 |
# |    clip_fraction        | 0.0257      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.347      |
# |    explained_variance   | 0.259       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0923      |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00283    |
# |    value_loss           | 0.159       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.33         |
# | time/                   |              |
# |    fps                  | 616          |
# |    iterations           | 50           |
# |    time_elapsed         | 166          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0032903678 |
# |    clip_fraction        | 0.0309       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.358       |
# |    explained_variance   | 0.249        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0837       |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00331     |
# |    value_loss           | 0.159        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.35         |
# | time/                   |              |
# |    fps                  | 616          |
# |    iterations           | 51           |
# |    time_elapsed         | 169          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0017361896 |
# |    clip_fraction        | 0.03         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.356       |
# |    explained_variance   | 0.245        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0914       |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00339     |
# |    value_loss           | 0.161        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.39         |
# | time/                   |              |
# |    fps                  | 615          |
# |    iterations           | 52           |
# |    time_elapsed         | 173          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0019980543 |
# |    clip_fraction        | 0.0219       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.343       |
# |    explained_variance   | 0.261        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0711       |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00295     |
# |    value_loss           | 0.157        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.29         |
# | time/                   |              |
# |    fps                  | 614          |
# |    iterations           | 53           |
# |    time_elapsed         | 176          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0030007926 |
# |    clip_fraction        | 0.0272       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.33        |
# |    explained_variance   | 0.261        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0958       |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.0038      |
# |    value_loss           | 0.163        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.44         |
# | time/                   |              |
# |    fps                  | 615          |
# |    iterations           | 54           |
# |    time_elapsed         | 179          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0019257222 |
# |    clip_fraction        | 0.0285       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.311       |
# |    explained_variance   | 0.284        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0653       |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00295     |
# |    value_loss           | 0.155        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.39         |
# | time/                   |              |
# |    fps                  | 615          |
# |    iterations           | 55           |
# |    time_elapsed         | 182          |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0020513781 |
# |    clip_fraction        | 0.0259       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.319       |
# |    explained_variance   | 0.242        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0748       |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00355     |
# |    value_loss           | 0.167        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.41         |
# | time/                   |              |
# |    fps                  | 614          |
# |    iterations           | 56           |
# |    time_elapsed         | 186          |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0025721143 |
# |    clip_fraction        | 0.0379       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.302       |
# |    explained_variance   | 0.261        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0739       |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.00363     |
# |    value_loss           | 0.165        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.31         |
# | time/                   |              |
# |    fps                  | 614          |
# |    iterations           | 57           |
# |    time_elapsed         | 190          |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0031391028 |
# |    clip_fraction        | 0.039        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.323       |
# |    explained_variance   | 0.274        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0703       |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.00271     |
# |    value_loss           | 0.151        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.3          |
# | time/                   |              |
# |    fps                  | 614          |
# |    iterations           | 58           |
# |    time_elapsed         | 193          |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0031144426 |
# |    clip_fraction        | 0.0388       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.33        |
# |    explained_variance   | 0.291        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0711       |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.00436     |
# |    value_loss           | 0.153        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.32        |
# | time/                   |             |
# |    fps                  | 615         |
# |    iterations           | 59          |
# |    time_elapsed         | 196         |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.002216252 |
# |    clip_fraction        | 0.0252      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.326      |
# |    explained_variance   | 0.253       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0639      |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.00276    |
# |    value_loss           | 0.16        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.23         |
# | time/                   |              |
# |    fps                  | 614          |
# |    iterations           | 60           |
# |    time_elapsed         | 200          |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0023188982 |
# |    clip_fraction        | 0.0344       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.33        |
# |    explained_variance   | 0.261        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0901       |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.00394     |
# |    value_loss           | 0.164        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.31         |
# | time/                   |              |
# |    fps                  | 613          |
# |    iterations           | 61           |
# |    time_elapsed         | 203          |
# |    total_timesteps      | 124928       |
# | train/                  |              |
# |    approx_kl            | 0.0023861332 |
# |    clip_fraction        | 0.0247       |
# ...
# |    fps                  | 605          |
# |    iterations           | 228          |
# |    time_elapsed         | 771          |
# |    total_timesteps      | 466944       |
# | train/                  |              |
# |    approx_kl            | 0.0026063104 |
# |    clip_fraction        | 0.0332       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.188       |
# |    explained_variance   | 0.361        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0789       |
# |    n_updates            | 2270         |
# |    policy_gradient_loss | 0.0013       |
# |    value_loss           | 0.156        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.43         |
# | time/                   |              |
# |    fps                  | 605          |
# |    iterations           | 229          |
# |    time_elapsed         | 774          |
# |    total_timesteps      | 468992       |
# | train/                  |              |
# |    approx_kl            | 0.0026503522 |
# |    clip_fraction        | 0.038        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.187       |
# |    explained_variance   | 0.36         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0787       |
# |    n_updates            | 2280         |
# |    policy_gradient_loss | -0.00242     |
# |    value_loss           | 0.153        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.33        |
# | time/                   |             |
# |    fps                  | 605         |
# |    iterations           | 230         |
# |    time_elapsed         | 777         |
# |    total_timesteps      | 471040      |
# | train/                  |             |
# |    approx_kl            | 0.004183538 |
# |    clip_fraction        | 0.048       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.184      |
# |    explained_variance   | 0.362       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0689      |
# |    n_updates            | 2290        |
# |    policy_gradient_loss | -0.00207    |
# |    value_loss           | 0.155       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.39        |
# | time/                   |             |
# |    fps                  | 605         |
# |    iterations           | 231         |
# |    time_elapsed         | 781         |
# |    total_timesteps      | 473088      |
# | train/                  |             |
# |    approx_kl            | 0.004522033 |
# |    clip_fraction        | 0.0447      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.188      |
# |    explained_variance   | 0.342       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0686      |
# |    n_updates            | 2300        |
# |    policy_gradient_loss | -0.00239    |
# |    value_loss           | 0.157       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.4          |
# | time/                   |              |
# |    fps                  | 605          |
# |    iterations           | 232          |
# |    time_elapsed         | 785          |
# |    total_timesteps      | 475136       |
# | train/                  |              |
# |    approx_kl            | 0.0035615556 |
# |    clip_fraction        | 0.0359       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.194       |
# |    explained_variance   | 0.34         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0751       |
# |    n_updates            | 2310         |
# |    policy_gradient_loss | -0.000928    |
# |    value_loss           | 0.156        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.38         |
# | time/                   |              |
# |    fps                  | 605          |
# |    iterations           | 233          |
# |    time_elapsed         | 788          |
# |    total_timesteps      | 477184       |
# | train/                  |              |
# |    approx_kl            | 0.0028046463 |
# |    clip_fraction        | 0.0359       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.178       |
# |    explained_variance   | 0.36         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0858       |
# |    n_updates            | 2320         |
# |    policy_gradient_loss | -0.00141     |
# |    value_loss           | 0.157        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.38         |
# | time/                   |              |
# |    fps                  | 605          |
# |    iterations           | 234          |
# |    time_elapsed         | 791          |
# |    total_timesteps      | 479232       |
# | train/                  |              |
# |    approx_kl            | 0.0038170693 |
# |    clip_fraction        | 0.0448       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.185       |
# |    explained_variance   | 0.358        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0707       |
# |    n_updates            | 2330         |
# |    policy_gradient_loss | -0.00179     |
# |    value_loss           | 0.154        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.37         |
# | time/                   |              |
# |    fps                  | 605          |
# |    iterations           | 235          |
# |    time_elapsed         | 794          |
# |    total_timesteps      | 481280       |
# | train/                  |              |
# |    approx_kl            | 0.0030117454 |
# |    clip_fraction        | 0.038        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.182       |
# |    explained_variance   | 0.366        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0736       |
# |    n_updates            | 2340         |
# |    policy_gradient_loss | -0.00276     |
# |    value_loss           | 0.151        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.4          |
# | time/                   |              |
# |    fps                  | 605          |
# |    iterations           | 236          |
# |    time_elapsed         | 798          |
# |    total_timesteps      | 483328       |
# | train/                  |              |
# |    approx_kl            | 0.0044269837 |
# |    clip_fraction        | 0.0349       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.173       |
# |    explained_variance   | 0.357        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0626       |
# |    n_updates            | 2350         |
# |    policy_gradient_loss | -0.000692    |
# |    value_loss           | 0.153        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.36         |
# | time/                   |              |
# |    fps                  | 605          |
# |    iterations           | 237          |
# |    time_elapsed         | 801          |
# |    total_timesteps      | 485376       |
# | train/                  |              |
# |    approx_kl            | 0.0059773084 |
# |    clip_fraction        | 0.0436       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.17        |
# |    explained_variance   | 0.39         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0817       |
# |    n_updates            | 2360         |
# |    policy_gradient_loss | 0.000144     |
# |    value_loss           | 0.148        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.45        |
# | time/                   |             |
# |    fps                  | 605         |
# |    iterations           | 238         |
# |    time_elapsed         | 804         |
# |    total_timesteps      | 487424      |
# | train/                  |             |
# |    approx_kl            | 0.004424288 |
# |    clip_fraction        | 0.0354      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.176      |
# |    explained_variance   | 0.348       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0814      |
# |    n_updates            | 2370        |
# |    policy_gradient_loss | -0.00148    |
# |    value_loss           | 0.156       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.41        |
# | time/                   |             |
# |    fps                  | 605         |
# |    iterations           | 239         |
# |    time_elapsed         | 808         |
# |    total_timesteps      | 489472      |
# | train/                  |             |
# |    approx_kl            | 0.003475959 |
# |    clip_fraction        | 0.0414      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.189      |
# |    explained_variance   | 0.369       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0544      |
# |    n_updates            | 2380        |
# |    policy_gradient_loss | -0.00208    |
# |    value_loss           | 0.151       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.42         |
# | time/                   |              |
# |    fps                  | 605          |
# |    iterations           | 240          |
# |    time_elapsed         | 812          |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0049486253 |
# |    clip_fraction        | 0.0454       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.18        |
# |    explained_variance   | 0.353        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0692       |
# |    n_updates            | 2390         |
# |    policy_gradient_loss | -0.00233     |
# |    value_loss           | 0.154        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.33         |
# | time/                   |              |
# |    fps                  | 605          |
# |    iterations           | 241          |
# |    time_elapsed         | 815          |
# |    total_timesteps      | 493568       |
# | train/                  |              |
# |    approx_kl            | 0.0032985297 |
# |    clip_fraction        | 0.0339       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.196       |
# |    explained_variance   | 0.361        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0861       |
# |    n_updates            | 2400         |
# |    policy_gradient_loss | 0.00103      |
# |    value_loss           | 0.153        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.45         |
# | time/                   |              |
# |    fps                  | 605          |
# |    iterations           | 242          |
# |    time_elapsed         | 818          |
# |    total_timesteps      | 495616       |
# | train/                  |              |
# |    approx_kl            | 0.0028873812 |
# |    clip_fraction        | 0.0424       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.185       |
# |    explained_variance   | 0.372        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0949       |
# |    n_updates            | 2410         |
# |    policy_gradient_loss | -0.00313     |
# |    value_loss           | 0.152        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.46         |
# | time/                   |              |
# |    fps                  | 605          |
# |    iterations           | 243          |
# |    time_elapsed         | 822          |
# |    total_timesteps      | 497664       |
# | train/                  |              |
# |    approx_kl            | 0.0031400467 |
# |    clip_fraction        | 0.0425       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.19        |
# |    explained_variance   | 0.365        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0346       |
# |    n_updates            | 2420         |
# |    policy_gradient_loss | -0.00161     |
# |    value_loss           | 0.154        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.29        |
# | time/                   |             |
# |    fps                  | 605         |
# |    iterations           | 244         |
# |    time_elapsed         | 825         |
# |    total_timesteps      | 499712      |
# | train/                  |             |
# |    approx_kl            | 0.002453859 |
# |    clip_fraction        | 0.0384      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.192      |
# |    explained_variance   | 0.349       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.078       |
# |    n_updates            | 2430        |
# |    policy_gradient_loss | -0.00114    |
# |    value_loss           | 0.155       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.46         |
# | time/                   |              |
# |    fps                  | 605          |
# |    iterations           | 245          |
# |    time_elapsed         | 828          |
# |    total_timesteps      | 501760       |
# | train/                  |              |
# |    approx_kl            | 0.0028692724 |
# |    clip_fraction        | 0.037        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.181       |
# |    explained_variance   | 0.353        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.074        |
# |    n_updates            | 2440         |
# |    policy_gradient_loss | -0.000844    |
# |    value_loss           | 0.154        |
# ------------------------------------------
# 🎯 Final DRL PPO Test Accuracy: 0.4300
